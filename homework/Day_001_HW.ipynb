# %% [markdown]
# # 作業一
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下<br>
# <br>
# [Suicide Rates Overview 1985 to 2016](https://www.kaggle.com/russellyates88/suicide-rates-overview-1985-to-2016)<br>
# 1. 你選的這組資料為何重要<br>
# We can find the crucial factor of the suicide through the machine learning. Futhermore, we can help preventing others from committing suicide.<br><br>
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)<br>
# From Kaggle by Rusty.
# The data are collected from <br>
# [United Nations Development Program](http://hdr.undp.org/en/indicators/137506)<br>
# [World Bank](http://databank.worldbank.org/data/source/world-development-indicators#)<br>
# [Szamil from Kaggle](https://www.kaggle.com/szamil/suicide-in-the-twenty-first-century/notebook)<br>
# [World Health Organization](http://www.who.int/mental_health/suicide-prevention/en/)<br><br>
# 3. 蒐集而來的資料型態為何<br>
# .csv file<br><br>
# 4. 這組資料想解決的問題如何評估<br>
# Try to find which elements (e.g. sex, age, GDP, HDI ... etc.) related to the increase of the suicide rate by using regression analysis.<br><br>

# %% [markdown]
# # 作業二
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：<br>
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)<br>
# How to minimize the cars to maximize the passengers. <br><br>
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)<br>
# Passenger Load Factor respect to the area and the time in a day. Use GPS to locate the car position and the drivers report the statuses.<br><br>
# 3. 蒐集而來的資料型態為何<br>
# x, y coordinate of the car position in runtime and statuses in numbers<br><br>
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)<br>
# Plot density map for the car positions with respect to the time in a day as well as the line graph of time and statuses<br><br>

# %% [markdown]
# # 作業三
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    """
    計算 MSE
    Args:
        - y: 實際值
        - y_hat: 預測值
    Return:
        - mse: MSE
    """
    mse = sum(( y - y_hat) ** 2) / len(y)
    
    return mse

# %%
def mean_absolute_error(y, y_hat):
    """
    計算 MAE
    Args:
        - y: 實際值
        - y_hat: 預測值
    Return:
        - mae: MAE
    """
    mae = sum(abs(y - y_hat)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 224.158
# The Mean absolute error is 11.835
